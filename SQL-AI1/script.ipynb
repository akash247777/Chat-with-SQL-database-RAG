-- %% [markdown]
-- # [Apollo_Pharmacy]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Apollo_Pharmacy]    Script Date: 02-05-2025 14:48:01 ******/
CREATE DATABASE [Apollo_Pharmacy]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Apollo_Pharmacy', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Apollo_Pharmacy.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Apollo_Pharmacy_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Apollo_Pharmacy_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Apollo_Pharmacy] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Apollo_Pharmacy].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Apollo_Pharmacy] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET ARITHABORT OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Apollo_Pharmacy] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Apollo_Pharmacy] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Apollo_Pharmacy] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Apollo_Pharmacy] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Apollo_Pharmacy] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Apollo_Pharmacy] SET  MULTI_USER 
GO
ALTER DATABASE [Apollo_Pharmacy] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Apollo_Pharmacy] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Apollo_Pharmacy] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Apollo_Pharmacy] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Apollo_Pharmacy] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Apollo_Pharmacy] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Apollo_Pharmacy] SET QUERY_STORE = ON
GO
ALTER DATABASE [Apollo_Pharmacy] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [akashsg]

-- %%
USE [Apollo_Pharmacy]
GO

-- %%
/****** Object:  User [akashsg]    Script Date: 02-05-2025 14:48:01 ******/
CREATE USER [akashsg] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [Akash]

-- %%
/****** Object:  User [Akash]    Script Date: 02-05-2025 14:48:01 ******/
CREATE USER [Akash] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[Medicine_Discounts]

-- %%
/****** Object:  Table [dbo].[Medicine_Discounts]    Script Date: 02-05-2025 14:48:02 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Medicine_Discounts](
	[Discount_ID] [int] NOT NULL,
	[Medicine_ID] [int] NULL,
	[Medicine_Discount] [decimal](5, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[Discount_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Medicines]

-- %%
/****** Object:  Table [dbo].[Medicines]    Script Date: 02-05-2025 14:48:02 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Medicines](
	[Medicine_ID] [int] NOT NULL,
	[Medicine_Name] [varchar](100) NULL,
	[Manufacture_Date] [date] NULL,
	[Expiry_Date] [date] NULL,
	[Dosage] [varchar](50) NULL,
	[Stock_Quantity] [int] NULL,
	[Price] [decimal](10, 2) NULL,
	[Category] [varchar](50) NULL,
	[Manufacturer] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Medicine_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Medicine___Medic__4BAC3F29]

-- %%
ALTER TABLE [dbo].[Medicine_Discounts]  WITH CHECK ADD FOREIGN KEY([Medicine_ID])
REFERENCES [dbo].[Medicines] ([Medicine_ID])
GO

-- %% [markdown]
-- # [Apollo_Pharmacy]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Apollo_Pharmacy] SET  READ_WRITE 
GO
